# %% [markdown]
# # **Racing Data Web Scraping Project**

# %% [markdown]
# ## **1\. Project Overview**
#
# The Racing Data Web Scraping Project aims to systematically collect and organize race data from [Fanatec GT world Challenge Europe](https://www.gt-world-challenge-europe.com/results?filter_season_id=0&filter_meeting_id=211&filter_race_id=) website. Utilizing Python, this project involves scraping detailed information about racing events, including seasons, meetings, and individual races, over designated periods. The primary objective is to capture this data in structured CSV files for further analysis.

# %% [markdown]
# ## **2\. Load Libraries**

# %%
import os
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ## **3\. Creating Functions**

# %% [markdown]
# ### **3.1. Function parse_years()**
#
# The `parse_years` function is designed to process various input formats for years, facilitating the versatile specification of years for which racing data should be retrieved. This function ensures that users can input single years, lists of years, or ranges of years.

# %%
def parse_years(input_years):
    # Processes input parameters for years, supporting specific years, lists, and ranges.
    if isinstance(input_years, list):
        return [str(year) for year in input_years]
    elif isinstance(input_years, str) and '-' in input_years:
        start_year, end_year = map(int, input_years.split('-'))
        return [str(year) for year in range(start_year, end_year + 1)]  # Including the end year
    elif isinstance(input_years, int):
        return [str(input_years)]  # Convert a single year into a list of strings
    return None

# %% [markdown]
# ### **3.2. Getting key value pairs**
#
# To obtain the results of a specific race via a URL, we need to know the values of the season, meeting, and race that we will insert into the URL. For instance, the 2023 season is represented as '23', the Monza track as '42', and the "Main Race" as '21'. We need to insert all these values into the URL. Therefore, we first need to acquire all the key-value pairs to use them later.

# %% [markdown]
# #### **3.2.1. Function get_seasons()**
#
# The function `get_seasons` is needed to obtain the key-value pairs for the season/seasons we are interested in.

# %%
def get_seasons():
    url = "https://www.gt-world-challenge-europe.com/results?filter_season_id=0&filter_meeting_id=0&filter_race_id="
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    seasons_options = soup.select('#filter_season_id option')
    seasons = {option.text.strip(): option['value'] for option in seasons_options if option['value']}
    
    return seasons

# %% [markdown]
# #### **3.2.2. Function get_meetings()**
#
# The function `get_meetings` is needed to obtain the key-value pairs of all race tracks in each season.

# %%
def get_meetings(season_id):
    url = f"https://www.gt-world-challenge-europe.com/results?filter_season_id={season_id}&filter_meeting_id=0&filter_race_id="
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    meetings_options = soup.select('#filter_meeting_id option')
    meetings = {option.text.strip(): option['value'] for option in meetings_options if option['value']}
    
    return meetings

# %% [markdown]
# #### **3.2.3. Function get_races()**
#
# The function `get_races` is needed to obtain the key-value pairs for all races on all tracks.

# %%
def get_races(season_id, meeting_id):
    url = f"https://www.gt-world-challenge-europe.com/results?filter_season_id={season_id}&filter_meeting_id={meeting_id}&filter_race_id="
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extracting all available race options from the dropdown list on the page
    races_options = soup.select('#filter_race_id option')
    
    # Skipping the first item as it's just a label, not an actual race
    races = [{'name': option.text.strip(), 'race_id': option['value']} for option in races_options if option['value']]
    
    return races

# %% [markdown]
# #### **3.2.4. Function load_race_data()**
# The function `load_race_data` uses all three functions to create one large list of all the key-value pairs, which we will use in the future.

# %%
def load_race_data(input_years=None):
    all_data = []
    seasons = get_seasons()

    years = parse_years(input_years)
    filtered_seasons = {year: id for year, id in seasons.items() if not years or year in years}

    for season, season_id in filtered_seasons.items():
        meetings = get_meetings(season_id)
        for meeting, meeting_id in meetings.items():
            races = get_races(season_id, meeting_id)
            all_data.append({
                "season": season,
                "season_id": season_id,
                "meeting": meeting,
                "meeting_id": meeting_id,
                "races": races
            })

    return all_data

# %% [markdown]
# ### **3.3. Using Key-Value Pairs**

# %% [markdown]
# #### **3.3.1. Function get_race_results()**
#
# With this function, we can obtain the results of a specific race by using the data obtained from the `load_race_data` function and specifying the season, meeting, and race_name of interest.

# %%
def get_race_results(season, meeting, race_name, race_data):
    # Searching for the season ID, meeting ID, and race ID based on the provided names
    season_id, meeting_id, race_id = None, None, None
    for data in race_data:
        if data['season'] == season and data['meeting'] == meeting:
            season_id = data['season_id']
            meeting_id = data['meeting_id']
            for race in data['races']:
                if race['name'] == race_name:
                    race_id = race['race_id']
                    break
            break

    if not season_id or not meeting_id or not race_id:
        raise ValueError("Cannot find specified race information.")

    # Formulating and executing the request
    final_url = f"https://www.gt-world-challenge-europe.com/results?filter_season_id={season_id}&filter_meeting_id={meeting_id}&filter_race_id={race_id}"
    response = requests.get(final_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Searching for the results table
    results_table = soup.find('table', {'class': 'table session'})
    if results_table is None:
        print(f"No results found for {race_name} in {meeting}, {season}.")
        return pd.DataFrame()

    # Extracting data from the table
    rows = results_table.find('tbody').find_all('tr')
    data = []
    for row in rows:
        cols = row.find_all('td')
        row_data = [col.text.strip() for col in cols]
        data.append(row_data)

    # Defining column names based on the first row of the table
    headers = [th.text.strip() for th in results_table.find('thead').find_all('th')]

    return pd.DataFrame(data, columns=headers)

# %% [markdown]
# #### **3.3.2. Function race_data_to_df()**
#
# The function `race_data_to_df` is needed to convert a List obtained using `load_race_data` into a DataFrame. This was necessary at the time of writing the code to check its correctness, monitor for bugs, and make corrections.

# %%
def race_data_to_df(race_data):
    # Preparing an empty list to store information about each race
    summary_data = []

    # We go through all the downloaded data to collect information
    for data in race_data:
        season = data['season']
        meeting = data['meeting']
        for race in data['races']:
            race_name = race['name']
            # Adding race information to the list
            summary_data.append({
                'Season': season,
                'Meeting': meeting,
                'Race Name': race_name
            })

    # Creating a DataFrame from the collected information
    summary_df = pd.DataFrame(summary_data)

    return summary_df

# %% [markdown]
# ### **3.4. Function for Saving CSVs**
#
# The `save_race_data_to_csv` function is designed to make queries(using `get_race_results`) and save results into CSV files based on specified filters like years, meetings, and types of races.
#
# The function also has options for organizing the saved files into folders.
# The `create_folders` parameter in `save_race_data_to_csv` affects how the data is organized into directories:<br>
# When `create_folders` is True:<br>
# The function creates additional subdirectories within each meeting's directory. These subdirectories are based on the type of race:
# * A subdirectory called "Qualifications" for races whose names contain "qualifying".
# * A subdirectory called "Races" for races whose names contain "race".

# %%
def save_race_data_to_csv(years=None, meetings=None, race_type=None, race_data=None, save_path='.', create_folders=False):
    if not race_data:
        print("No data to process.")
        return

    if isinstance(years, str):
        years = parse_years(years)
    if isinstance(meetings, str):
        meetings = [meetings]
    if race_type and isinstance(race_type, str):
        race_type = [race_type.lower()]

    data_dir = os.path.join(save_path, 'data_csv')
    os.makedirs(data_dir, exist_ok=True)
    
    for data in race_data:
        if years and data['season'] not in years:
            continue
        if meetings and data['meeting'] not in meetings:
            continue
        
        meeting_dir = os.path.join(data_dir, data['season'], data['meeting'].replace(" ", "_"))
        os.makedirs(meeting_dir, exist_ok=True)
        
        for race in data['races']:
            if race_type:
                # Check for a match with the specified race type
                if not any(r.lower() == race['name'].lower() for r in race_type):
                    continue  # Skip the race if it does not match the specified type
            
            # Determine the save path based on the create_folders flag and race name
            folder_path = meeting_dir
            if create_folders:
                if "qualifying" in race['name'].lower():
                    folder_path = os.path.join(meeting_dir, "Qualifications")
                elif "race" in race['name'].lower(): 
                    folder_path = os.path.join(meeting_dir, "Races")
                os.makedirs(folder_path, exist_ok=True)
            
            file_path = os.path.join(folder_path, f"{race['name'].replace(' ', '_')}.csv")
            try:
                df = get_race_results(data['season'], data['meeting'], race['name'], race_data)
                if not df.empty:
                    df.to_csv(file_path, index=False)
                    print(f"Saved: {file_path}")
                else:
                    print(f"No results found for {race['name']} in {data['meeting']}, {data['season']}.")
            except Exception as e:
                print(f"Error saving {race['name']} in {data['meeting']}, {data['season']}: {e}")

# %% [markdown]
# ## **4. Using Functions**

# %% [markdown]
# ### **4.1. Load Data**

# %%
my_race_data = load_race_data(["2021", "2022", "2023"])

# %% [markdown]
# ### **4.2. A Quick Check That Everything is Working**

# %%
race_summary_df = race_data_to_df(my_race_data)

race_summary_df.head(5)
# Out:
#   Season Meeting                   Race Name
# 0   2023   Monza  Main Race after 2.30 hours
# 1   2023   Monza   Main Race after 1.30 hour
# 2   2023   Monza     Main Race after 30 mins
# 3   2023   Monza                   Main Race
# 4   2023   Monza         Combined Qualifying

# %%
meetings = race_summary_df['Meeting'].drop_duplicates().reset_index(drop=True)
results = race_summary_df[race_summary_df['Meeting'] == 'Brands Hatch']['Race Name'].reset_index(drop=True)
print(meetings.head(10))
print(results.head())
# Out:
# 0                          Monza
# 1                   Brands Hatch
# 2     Circuit Paul Ricard 1000Km
# 3    CrowdStrike 24 Hours of Spa
# 4                         Misano
# 5                    Nürburgring
# 6                     Hockenheim
# 7                       Valencia
# 8                      Barcelona
# 9                      Zandvoort
# Name: Meeting, dtype: object
# 0          Race 2
# 1          Race 1
# 2        Pit walk
# 3    Qualifying 2
# 4    Qualifying 1
# Name: Race Name, dtype: object

# %%
df = get_race_results("2021", "Brands Hatch", "Race 1", my_race_data)

df.head()
# Out:
#   Pos Car #       Class  ...      Time Laps     Gap
# 0   1    32     Pro Cup  ...  1:24.933   40
# 1   2     6     Pro Cup  ...  1:25.202   40   0.407
# 2   3    31  Silver Cup  ...  1:25.748   40   8.487
# 3   4    90  Silver Cup  ...  1:25.536   40   9.730
# 4   5    26     Pro Cup  ...  1:25.798   40  10.438
#
# [5 rows x 9 columns]

# %% [markdown]
# ### **4.3. Save All Data**

# %%
save_race_data_to_csv(years=["2021", "2022", "2023"], race_data=my_race_data, create_folders=True)
# Out:
# Saved: .\data_csv\2023\Monza\Races\Main_Race_after_2.30_hours.csv
# Saved: .\data_csv\2023\Monza\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2023\Monza\Races\Main_Race_after_30_mins.csv
# Saved: .\data_csv\2023\Monza\Races\Main_Race.csv
# Saved: .\data_csv\2023\Monza\Qualifications\Combined_Qualifying.csv
# No results found for Qualifying 3 in Monza, 2023.
# Saved: .\data_csv\2023\Monza\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2023\Monza\Qualifications\Qualifying_1.csv
# No results found for Pit walk in Monza, 2023.
# No results found for Fanatec Esports GT Pro Series in Monza, 2023.
# No results found for Fanatec Esports GT Pro Series in Monza, 2023.
# Saved: .\data_csv\2023\Monza\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2023\Monza\Free_practice.csv
# Saved: .\data_csv\2023\Monza\Bronze_Test.csv
# Saved: .\data_csv\2023\Brands_Hatch\Races\Race_2.csv
# Saved: .\data_csv\2023\Brands_Hatch\Races\Race_1.csv
# No results found for Pit walk in Brands Hatch, 2023.
# Saved: .\data_csv\2023\Brands_Hatch\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2023\Brands_Hatch\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2023\Brands_Hatch\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2023\Brands_Hatch\Free_practice.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_5.30_hours.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Races\Main_race_after_4.30_hours.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_3.30_hours.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_2.30_hours.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Races\Main_Race.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Qualifications\Combined_Qualifying.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Qualifications\Pre_Qualifying_Practice.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Free_practice.csv
# Saved: .\data_csv\2023\Circuit_Paul_Ricard_1000Km\Bronze_Test.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_23_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_22_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_21_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_20_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_19_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_18_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_17_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_16_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_16_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_15_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_14_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_13_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_12_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_11_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_10_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_9_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_8_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_7_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_6_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_5_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_4_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_3_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_2_hours.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Races\Main_Race_after_1_hour.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Warm-up.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Super_Pole.csv
# No results found for Night Practice in CrowdStrike 24 Hours of Spa, 2023.
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Qualifications\Combined_Qualifying.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Qualifications\Qualifying_4.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Free_practice.csv
# Saved: .\data_csv\2023\CrowdStrike_24_Hours_of_Spa\Bronze_Test.csv
# Saved: .\data_csv\2023\Misano\Races\Race_2.csv
# Saved: .\data_csv\2023\Misano\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2023\Misano\Races\Race_1.csv
# Saved: .\data_csv\2023\Misano\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2023\Misano\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2023\Misano\Free_practice.csv
# Saved: .\data_csv\2023\Misano\Official_Paid_Test_Sessions_1.csv
# Saved: .\data_csv\2023\Nürburgring\Races\Main_Race_after_2.30_hours.csv
# Saved: .\data_csv\2023\Nürburgring\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2023\Nürburgring\Races\Main_Race.csv
# Saved: .\data_csv\2023\Nürburgring\Qualifications\Combined_Qualifying.csv
# Saved: .\data_csv\2023\Nürburgring\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2023\Nürburgring\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2023\Nürburgring\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2023\Nürburgring\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2023\Nürburgring\Free_practice.csv
# Saved: .\data_csv\2023\Nürburgring\Bronze_Test.csv
# Saved: .\data_csv\2023\Nürburgring\Official_Paid_Test_Sessions_1.csv
# Saved: .\data_csv\2023\Nürburgring\Official_Paid_Test_Sessions_1.csv
# Saved: .\data_csv\2023\Hockenheim\Races\Race_2.csv
# Saved: .\data_csv\2023\Hockenheim\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2023\Hockenheim\Races\Race_1.csv
# Saved: .\data_csv\2023\Hockenheim\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2023\Hockenheim\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2023\Hockenheim\Free_practice.csv
# Saved: .\data_csv\2023\Hockenheim\Official_Paid_Test_Sessions_1.csv
# Saved: .\data_csv\2023\Valencia\Races\Race_2.csv
# Saved: .\data_csv\2023\Valencia\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2023\Valencia\Races\Race_1.csv
# Saved: .\data_csv\2023\Valencia\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2023\Valencia\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2023\Valencia\Free_practice.csv
# Saved: .\data_csv\2023\Valencia\Official_Paid_Test_Sessions_1.csv
# Saved: .\data_csv\2023\Barcelona\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2023\Barcelona\Races\Main_Race.csv
# Saved: .\data_csv\2023\Barcelona\Qualifications\Combined_Qualifying.csv
# Saved: .\data_csv\2023\Barcelona\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2023\Barcelona\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2023\Barcelona\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2023\Barcelona\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2023\Barcelona\Free_practice.csv
# Saved: .\data_csv\2023\Barcelona\Bronze_Test.csv
# Saved: .\data_csv\2023\Barcelona\Official_Paid_Test_Session_2.csv
# Saved: .\data_csv\2023\Barcelona\Official_Paid_Test_Sessions_1.csv
# Saved: .\data_csv\2023\Zandvoort\Races\Race_2.csv
# Saved: .\data_csv\2023\Zandvoort\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2023\Zandvoort\Races\Race_1.csv
# Saved: .\data_csv\2023\Zandvoort\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2023\Zandvoort\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2023\Zandvoort\Free_practice.csv
# Saved: .\data_csv\2022\Imola\Races\Main_Race_after_2.30_hours.csv
# Saved: .\data_csv\2022\Imola\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2022\Imola\Races\Main_Race_after_30_mins.csv
# Saved: .\data_csv\2022\Imola\Races\Main_Race.csv
# No results found for Combined Qualifying in Imola, 2022.
# Saved: .\data_csv\2022\Imola\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2022\Imola\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2022\Imola\Qualifications\Qualifying_1.csv
# No results found for Fanatec Esports GT Pro Series in Imola, 2022.
# No results found for Fanatec Esports GT Pro Series in Imola, 2022.
# Saved: .\data_csv\2022\Imola\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2022\Imola\Free_practice.csv
# Saved: .\data_csv\2022\Imola\Bronze_Test.csv
# Saved: .\data_csv\2022\Imola\Official_Paid_Test_Sessions_1.csv
# Saved: .\data_csv\2022\Brands_Hatch\Races\Race_2.csv
# Saved: .\data_csv\2022\Brands_Hatch\Races\Race_1.csv
# Saved: .\data_csv\2022\Brands_Hatch\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2022\Brands_Hatch\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2022\Brands_Hatch\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2022\Brands_Hatch\Free_practice.csv
# Saved: .\data_csv\2022\Magny-Cours\Races\Race_2.csv
# Saved: .\data_csv\2022\Magny-Cours\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2022\Magny-Cours\Races\Race_1.csv
# Saved: .\data_csv\2022\Magny-Cours\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2022\Magny-Cours\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2022\Magny-Cours\Free_practice.csv
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_5.30_hours.csv
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Races\Main_race_after_4.30_hours.csv
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_3.30_hours.csv
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_2.30_hours.csv
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_30_mins.csv
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Races\Main_Race.csv
# No results found for Combined Qualifying in Circuit Paul Ricard 1000Km, 2022.
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Qualifications\Pre_Qualifying.csv
# No results found for Fanatec Esports GT Pro Series in Circuit Paul Ricard 1000Km, 2022.
# No results found for Fanatec Esports GT Pro Series in Circuit Paul Ricard 1000Km, 2022.
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Free_practice.csv
# Saved: .\data_csv\2022\Circuit_Paul_Ricard_1000Km\Bronze_Test.csv
# Saved: .\data_csv\2022\Zandvoort\Races\Race_2.csv
# Saved: .\data_csv\2022\Zandvoort\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2022\Zandvoort\Races\Race_1.csv
# Saved: .\data_csv\2022\Zandvoort\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2022\Zandvoort\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2022\Zandvoort\Free_practice.csv
# Saved: .\data_csv\2022\Misano\Races\Race_2.csv
# Saved: .\data_csv\2022\Misano\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2022\Misano\Races\Race_1.csv
# Saved: .\data_csv\2022\Misano\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2022\Misano\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2022\Misano\Free_practice.csv
# Saved: .\data_csv\2022\Misano\Official_Paid_Test_Sessions_1.csv
# No results found for  in TotalEnergies 24 Hours of Spa, 2022.
# No results found for  in TotalEnergies 24 Hours of Spa, 2022.
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_23_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_22_Hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_21_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_20_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_19_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_18_hours.csv
# No results found for Main Race after 17 hours in TotalEnergies 24 Hours of Spa, 2022.
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_16_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_15_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_14_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_13_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_12_hours.csv
# No results found for Main Race after 11 hours in TotalEnergies 24 Hours of Spa, 2022.
# No results found for Main Race after 10 hours in TotalEnergies 24 Hours of Spa, 2022.
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_9_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_8_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_7_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_6_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_5_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_4_hours.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_3_hours.csv
# No results found for Main Race after 2 hours in TotalEnergies 24 Hours of Spa, 2022.
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_30_mins.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Races\Main_Race.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Super_Pole.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Warm-up.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Qualifications\Combined_Qualifying.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Qualifications\Qualifying_4.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Free_practice.csv
# Saved: .\data_csv\2022\TotalEnergies_24_Hours_of_Spa\Bronze_Test.csv
# Saved: .\data_csv\2022\Hockenheim\Races\Main_Race_after_2.30_hours.csv
# Saved: .\data_csv\2022\Hockenheim\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2022\Hockenheim\Races\Main_Race.csv
# Saved: .\data_csv\2022\Hockenheim\Qualifications\Qualifying_Combined.csv
# Saved: .\data_csv\2022\Hockenheim\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2022\Hockenheim\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2022\Hockenheim\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2022\Hockenheim\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2022\Hockenheim\Free_practice.csv
# Saved: .\data_csv\2022\Hockenheim\Bronze_Test.csv
# Saved: .\data_csv\2022\Hockenheim\Official_test_sessions.csv
# Saved: .\data_csv\2022\Valencia\Races\Race_2.csv
# Saved: .\data_csv\2022\Valencia\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2022\Valencia\Races\Race_1.csv
# Saved: .\data_csv\2022\Valencia\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2022\Valencia\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2022\Valencia\Free_practice.csv
# Saved: .\data_csv\2022\Valencia\Official_Paid_Test_Sessions_1.csv
# Saved: .\data_csv\2022\Barcelona\Races\Main_Race_after_2.30_hours.csv
# Saved: .\data_csv\2022\Barcelona\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2022\Barcelona\Races\Main_Race.csv
# Saved: .\data_csv\2022\Barcelona\Qualifications\Combined_Qualifying.csv
# Saved: .\data_csv\2022\Barcelona\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2022\Barcelona\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2022\Barcelona\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2022\Barcelona\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2022\Barcelona\Free_practice.csv
# Saved: .\data_csv\2022\Barcelona\Bronze_Test.csv
# Saved: .\data_csv\2022\Barcelona\Official_Paid_Test_Sessions_1.csv
# Saved: .\data_csv\2022\Barcelona\Official_Paid_Test_Sessions_1.csv
# Saved: .\data_csv\2021\Monza\Races\Main_Race_after_2.30_hours.csv
# Saved: .\data_csv\2021\Monza\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2021\Monza\Races\Main_Race.csv
# Saved: .\data_csv\2021\Monza\Qualifications\Combined_Qualifying.csv
# Saved: .\data_csv\2021\Monza\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2021\Monza\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2021\Monza\Qualifications\Qualifying_1.csv
# No results found for Fanatec Esports GT Pro Series in Monza, 2021.
# No results found for Fanatec Esports GT Pro Series in Monza, 2021.
# Saved: .\data_csv\2021\Monza\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2021\Monza\Free_practice.csv
# No results found for Bronze Test in Monza, 2021.
# Saved: .\data_csv\2021\Monza\Official_test_sessions.csv
# Saved: .\data_csv\2021\Magny-Cours\Races\Race_2.csv
# Saved: .\data_csv\2021\Magny-Cours\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2021\Magny-Cours\Races\Race_1.csv
# Saved: .\data_csv\2021\Magny-Cours\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2021\Magny-Cours\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2021\Magny-Cours\Free_practice.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Races\Main_race_after_4.30_hours.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_3.30_hours.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_2.30_hours.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Races\Main_Race_after_30_mins.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Races\Main_Race.csv
# No results found for Fanatec Esports GT Pro Series in Circuit Paul Ricard 1000Km, 2021.
# No results found for Fanatec Esports GT Pro Series in Circuit Paul Ricard 1000Km, 2021.
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Qualifications\Combined_Qualifying.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Free_practice.csv
# Saved: .\data_csv\2021\Circuit_Paul_Ricard_1000Km\Bronze_Test.csv
# Saved: .\data_csv\2021\Zandvoort\Races\Race_2.csv
# Saved: .\data_csv\2021\Zandvoort\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2021\Zandvoort\Races\Race_1.csv
# Saved: .\data_csv\2021\Zandvoort\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2021\Zandvoort\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2021\Zandvoort\Free_practice.csv
# Saved: .\data_csv\2021\Misano\Races\Race_2.csv
# Saved: .\data_csv\2021\Misano\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2021\Misano\Races\Race_1.csv
# Saved: .\data_csv\2021\Misano\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2021\Misano\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2021\Misano\Free_practice.csv
# Saved: .\data_csv\2021\Misano\Official_test_sessions.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_22_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_21_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_20_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_19_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_18_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_17_hours.csv
# No results found for Main Race after 16 hours in TotalEnergies 24 Hours of Spa, 2021.
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_15_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_14_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_13_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_12_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_11_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_10_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_9_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_8_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_7_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_6_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_5_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_4_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_3_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_2_hours.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race_after_1_hour.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Races\Main_Race.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Super_Pole.csv
# No results found for Warm-up in TotalEnergies 24 Hours of Spa, 2021.
# No results found for Fanatec Esports GT Pro Series in TotalEnergies 24 Hours of Spa, 2021.
# No results found for Fanatec Esports GT Pro Series in TotalEnergies 24 Hours of Spa, 2021.
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Night_Practice.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Qualifications\Combined_Qualifying.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Qualifications\Qualifying_4.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Free_practice.csv
# Saved: .\data_csv\2021\TotalEnergies_24_Hours_of_Spa\Bronze_Test.csv
# Saved: .\data_csv\2021\Brands_Hatch\Races\Race_2.csv
# Saved: .\data_csv\2021\Brands_Hatch\Races\Race_1.csv
# Saved: .\data_csv\2021\Brands_Hatch\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2021\Brands_Hatch\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2021\Brands_Hatch\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2021\Brands_Hatch\Free_practice.csv
# Saved: .\data_csv\2021\Nürburgring\Races\Main_Race_after_2.30_hours.csv
# Saved: .\data_csv\2021\Nürburgring\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2021\Nürburgring\Races\Main_Race.csv
# No results found for Combined Qualifying in Nürburgring, 2021.
# Saved: .\data_csv\2021\Nürburgring\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2021\Nürburgring\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2021\Nürburgring\Qualifications\Qualifying_1.csv
# No results found for Fanatec Esports GT Pro Series in Nürburgring, 2021.
# No results found for Fanatec Esports GT Pro Series in Nürburgring, 2021.
# Saved: .\data_csv\2021\Nürburgring\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2021\Nürburgring\Free_practice.csv
# Saved: .\data_csv\2021\Nürburgring\Bronze_Test.csv
# Saved: .\data_csv\2021\Nürburgring\Official_test_sessions.csv
# Saved: .\data_csv\2021\Nürburgring\Official_test_sessions.csv
# Saved: .\data_csv\2021\Valencia\Races\Race_2.csv
# Saved: .\data_csv\2021\Valencia\Races\Race_1.csv
# Saved: .\data_csv\2021\Valencia\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2021\Valencia\Qualifications\Qualifying_1.csv
# Saved: .\data_csv\2021\Valencia\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2021\Valencia\Free_practice.csv
# Saved: .\data_csv\2021\Valencia\Official_test_sessions.csv
# Saved: .\data_csv\2021\Barcelona\Races\Main_Race_after_2.30_hours.csv
# Saved: .\data_csv\2021\Barcelona\Races\Main_Race_after_1.30_hour.csv
# Saved: .\data_csv\2021\Barcelona\Races\Main_Race.csv
# No results found for Combined Qualifying in Barcelona, 2021.
# Saved: .\data_csv\2021\Barcelona\Qualifications\Qualifying_3.csv
# Saved: .\data_csv\2021\Barcelona\Qualifications\Qualifying_2.csv
# Saved: .\data_csv\2021\Barcelona\Qualifications\Qualifying_1.csv
# No results found for Fanatec Esports GT Pro Series in Barcelona, 2021.
# No results found for Fanatec Esports GT Pro Series in Barcelona, 2021.
# Saved: .\data_csv\2021\Barcelona\Qualifications\Pre_Qualifying.csv
# Saved: .\data_csv\2021\Barcelona\Free_practice.csv
# Saved: .\data_csv\2021\Barcelona\Bronze_Test.csv
# Saved: .\data_csv\2021\Barcelona\Official_test_sessions.csv
# Saved: .\data_csv\2021\Barcelona\Official_test_sessions.csv
